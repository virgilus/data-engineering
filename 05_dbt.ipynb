# %% [markdown]
# # Introduction to dbt (Data Build Tool)
#
# ## 🛠️ What is dbt?
#
# **dbt (data build tool)** is a modern data transformation tool that has become a cornerstone of today’s analytics engineering workflows. Built on top of **SQL**  and **Jinja**, dbt enables data teams to transform raw data in their data warehouses into clean, well-structured, and tested analytics tables.
#
# Over the past few years, dbt has gained massive adoption across the data industry, supported by a large and active community. This popularity is not accidental: dbt fundamentally changes how data transformations are built, managed, and scaled.
#
# ---
#
# ## 🚀 Why dbt Became Popular
#
# To understand dbt’s impact, it helps to look at how data pipelines were built in the past.
#
# ### 🕰️ Before dbt: Traditional Data Pipelines
#
# Historically, data pipelines relied on a wide variety of tools:
#
# * 🔧 SSIS, Informatica, SAP, Oracle tools
# * 📜 Stored procedures and SQL scripts scheduled with cron jobs ⏰ or Windows Task Scheduler
# * 🐍 Python pipelines wrapping SQL transformations
# * ⚙️ Orchestration tools like Airflow 🌬️ doing *everything* at once
#
# Although SQL was always at the core, engineers had to master **many different tools** just to run and maintain transformations. This increased the technical barrier and made pipelines harder to maintain, test, and scale.
#
# ---
#
# ## 🔄 The Shift to the Modern Data Stack
#
# As the ecosystem evolved:
#
# * 📥 Tools like **Fivetran**, **Airbyte**, and **Meltano** specialized in **data ingestion**
# * 🕒 Orchestration tools focused on scheduling
# * 🛠️ dbt emerged as a dedicated solution for the **transformation (T) layer**
#
# This “unbundling” of the data pipeline allowed each tool to do one thing well.
#
# ---
#
# ## 💡 What dbt Really Does
#
# At its core, dbt:
#
# * 🏗️ Runs SQL transformations inside your **data warehouse**
# * 🧩 Uses **Jinja templating** to make SQL modular and reusable
# * 💻 Applies **software engineering best practices** to analytics
#
# With dbt, SQL becomes more than ad-hoc analysis. It becomes:
#
# * 🗂️ Version-controlled (Git)
# * ✅ Testable
# * 🧱 Modular
# * 🔁 Repeatable
# * 🌍 Environment-aware (dev, staging, production)
#
# In other words, dbt turns SQL into **production-grade code**.
#
# ---
#
# ## ⚙️ How dbt Works (High-Level)
#
# 1. 📥 Install dbt (e.g. via `pip install dbt` 📦)
# 2. 📁 Initialize a dbt project
# 3. ✍️ Write SQL models in the `models/` directory
# 4. 🔄 dbt compiles SQL + Jinja into executable SQL
# 5. ▶️ dbt runs those queries in your data warehouse
# 6. 📊 Each model materializes as a table or view
# 7. 📑 Tests and documentation are automatically generated and executed
#
# All transformations live **inside the warehouse**, reducing complexity and external dependencies.
#
# ---
#
# ## ⚖️ Pros and Cons of dbt
#
# ### 👍 Pros
#
# * 🔓 Open source and extensible
# * 📜 Built-in version control and testing
# * 🧠 SQL-first (no heavy programming required)
# * 📚 Strong documentation and community
# * 🔗 Fits naturally into ELT workflows
#
# ### 👎 Cons
#
# * 🕸️ SQL logic can become complex
# * 🐛 Limited debugging for custom macros
# * 🚧 dbt only handles transformations (T), not ingestion or orchestration
# * 🏗️ Requires solid data modeling fundamentals
#
# ---
#
# ## 🗺️ Where dbt Fits in the Data Stack
#
# dbt is designed for **ELT architectures**, where:
#
# 1. 🚛 Data is loaded raw into the warehouse.
# 2. ✨ dbt transforms it into analytics-ready tables
#
# While this requires other tools for ingestion and orchestration, dbt excels at what it is designed to do.
